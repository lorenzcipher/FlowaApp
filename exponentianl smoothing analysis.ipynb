# %%
import pandas as pd
from functions.analysis_and_plots import (preprocessing, train_test_split, plot_train_test_data,
seasonal_decompose_plot, exp_smoothing_model, exponential_smoothing_plot, rms_error_calc, load_model, predict_with_model, cumulative_addition, get_tables_from_sheet,create_df,sum_columns,subtract_dataframes)

# %%
# Define the index
index_depenses = [
    "Loyer", "Restaurant", "Telephone", "Shopping", "Coffee",
    "Transports", "Electricte", "Netflix", "Divers Amazon", "Salle de sport",
    "Divers", "Autres"
]

index_revenus = ["Salaire"]

# Load the Excel file
file_path = 'CFF.xlsx'
sheet_name = 'CFF'

tables = get_tables_from_sheet(file_path, sheet_name)


revenus = tables[0]
depenses = tables[2]

# %%
revenus
# Out:
#       Date  2024-08-01 00:00:00  2024-08-08 00:00:00  2024-08-15 00:00:00  \
# 0  REVENUS                  NaN                  NaN                  NaN
# 1  Salaire               3500.0                  NaN                  NaN
# 2    Vente                  NaN                  NaN                  NaN
# 3  Autres                   NaN                  NaN                  NaN
#
#    2024-08-22 00:00:00  2024-08-29 00:00:00  2024-09-05 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN               3500.0                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
#
#    2024-09-12 00:00:00  2024-09-19 00:00:00  2024-09-26 00:00:00  ...  \
# 0                  NaN                  NaN                  NaN  ...
# 1                  NaN                  NaN               3500.0  ...
# 2                  NaN                  NaN                  NaN  ...
# 3                  NaN                  NaN                  NaN  ...
#
#    2024-11-21 00:00:00  2024-11-28 00:00:00  2024-12-05 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1               3500.0                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
#
#    2024-12-12 00:00:00  2024-12-19 00:00:00  2024-12-26 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN               3500.0                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
#
#    2025-01-02 00:00:00  2025-01-09 00:00:00  2025-01-16 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
#
#    2025-01-23 00:00:00
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
#
# [4 rows x 27 columns]

# %%
depenses
# Out:
#                Date  2024-08-01 00:00:00  2024-08-08 00:00:00  \
# 7         DEPENSES                   NaN                  NaN
# 8            Loyer               1200.00                  NaN
# 9        Restaurant                60.00                 60.0
# 10       Telephone                   NaN                 30.0
# 11         Shopping               210.00                180.0
# 12           Coffee                 5.00                  5.0
# 13      Transports                   NaN                 50.0
# 14       Electricte                  NaN                  NaN
# 15          Netflix                15.99                  NaN
# 16    Divers Amazon                  NaN                120.0
# 17  Salle de sport                   NaN                  NaN
# 18          Divers                   NaN                  NaN
# 19           Autres                  NaN                  NaN
#
#     2024-08-15 00:00:00  2024-08-22 00:00:00  2024-08-29 00:00:00  \
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN               1200.0
# 9                   NaN                 70.0                 70.0
# 10                  NaN                  NaN                  NaN
# 11                120.0                130.0                200.0
# 12                  NaN                  NaN                  5.0
# 13                 50.0                 50.0                 50.0
# 14                  NaN                 60.0                  NaN
# 15                  NaN                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 17                  NaN                 40.0                  NaN
# 18                 45.0                  NaN                 30.0
# 19                 80.0                  NaN                  NaN
#
#     2024-09-05 00:00:00  2024-09-12 00:00:00  2024-09-19 00:00:00  \
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                 60.00                  NaN                 70.0
# 10                  NaN                 30.0                  NaN
# 11               140.00                100.0                120.0
# 12                  NaN                  5.0                  NaN
# 13                50.00                 50.0                 50.0
# 14                  NaN                  NaN                  NaN
# 15                15.99                  NaN                  NaN
# 16                  NaN                  NaN                  NaN
# 17                  NaN                  NaN                 40.0
# 18                  NaN                 45.0                  NaN
# 19                  NaN                 80.0                  NaN
#
#     2024-09-26 00:00:00  ...  2024-11-21 00:00:00  2024-11-28 00:00:00  \
# 7                   NaN  ...                  NaN                  NaN
# 8                1200.0  ...               1200.0                  NaN
# 9                  70.0  ...                 70.0                 70.0
# 10                  NaN  ...                  NaN                  NaN
# 11                180.0  ...                120.0                180.0
# 12                  NaN  ...                  NaN                  NaN
# 13                 50.0  ...                 50.0                100.0
# 14                 60.0  ...                  NaN                 60.0
# 15                  NaN  ...                  NaN                  NaN
# 16                  NaN  ...                  NaN                  NaN
# 17                  NaN  ...                 40.0                  NaN
# 18                  NaN  ...                 45.0                  NaN
# 19                 30.0  ...                  NaN                 30.0
#
#     2024-12-05 00:00:00  2024-12-12 00:00:00  2024-12-19 00:00:00  \
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN               1200.0
# 9                   NaN                  NaN                 70.0
# 10                  NaN                 30.0                  NaN
# 11               210.00                100.0                120.0
# 12                 5.00                  5.0                  NaN
# 13                  NaN                  NaN                 50.0
# 14                  NaN                  NaN                  NaN
# 15                15.99                  NaN                  NaN
# 16                  NaN                120.0                  NaN
# 17                  NaN                  NaN                 40.0
# 18                  NaN                  NaN                 45.0
# 19                  NaN                 80.0                  NaN
#
#     2024-12-26 00:00:00  2025-01-02 00:00:00  2025-01-09 00:00:00  \
# 7                   NaN                  NaN                  NaN
# 8                   NaN                  NaN                  NaN
# 9                  70.0                  NaN                  NaN
# 10                  NaN                  NaN                 30.0
# 11                180.0               210.00                100.0
# 12                  NaN                 5.00                  5.0
# 13                100.0                  NaN                  NaN
# 14                 60.0                  NaN                  NaN
# 15                  NaN                15.99                  NaN
# 16                  NaN                  NaN                120.0
# 17                  NaN                  NaN                  NaN
# 18                  NaN                  NaN                  NaN
# 19                 30.0                  NaN                 80.0
#
#     2025-01-16 00:00:00  2025-01-23 00:00:00
# 7                   NaN                  NaN
# 8                1200.0                  NaN
# 9                  70.0                 70.0
# 10                  NaN                  NaN
# 11                120.0                180.0
# 12                  NaN                  NaN
# 13                 50.0                100.0
# 14                  NaN                 60.0
# 15                  NaN                  NaN
# 16                  NaN                  NaN
# 17                 40.0                  NaN
# 18                 45.0                  NaN
# 19                  NaN                 30.0
#
# [13 rows x 27 columns]

# %%
df_revenus = preprocessing(revenus)
df_depense = preprocessing(depenses)

# %%
df_revenus
# Out:
#    2024-08-01 2024-08-08 2024-08-15 2024-08-22  2024-08-29 2024-09-05  \
# 1      3500.0                                       3500.0
#
#   2024-09-12 2024-09-19  2024-09-26 2024-10-03  ... 2024-11-21 2024-11-28  \
# 1                            3500.0             ...     3500.0
#
#    2024-12-05 2024-12-12 2024-12-19 2024-12-26  2025-01-02 2025-01-09  \
# 1                            3500.0
#
#   2025-01-16 2025-01-23
# 1
#
# [1 rows x 26 columns]

# %%
df_depense
# Out:
#    2024-08-01 2024-08-08 2024-08-15 2024-08-22 2024-08-29 2024-09-05  \
# 8      1200.0                                      1200.0
# 9        60.0       60.0                  70.0       70.0       60.0
# 10                  30.0
# 11      210.0      180.0      120.0      130.0      200.0      140.0
# 12        5.0        5.0                              5.0
# 13                  50.0       50.0       50.0       50.0       50.0
# 14                                        60.0
# 15      15.99                                                  15.99
# 16                 120.0
# 17                                        40.0
# 18                             45.0                  30.0
# 19                             80.0
#
#    2024-09-12 2024-09-19 2024-09-26 2024-10-03  ... 2024-11-21 2024-11-28  \
# 8                            1200.0             ...     1200.0
# 9                   70.0       70.0       60.0  ...       70.0       70.0
# 10       30.0                                   ...
# 11      100.0      120.0      180.0      290.0  ...      120.0      180.0
# 12        5.0                              5.0  ...
# 13       50.0       50.0       50.0       50.0  ...       50.0      100.0
# 14                             60.0             ...                  60.0
# 15                                       15.99  ...
# 16                                              ...
# 17                  40.0                        ...       40.0
# 18       45.0                                   ...       45.0
# 19       80.0                  30.0             ...                  30.0
#
#    2024-12-05 2024-12-12 2024-12-19 2024-12-26 2025-01-02 2025-01-09  \
# 8                            1200.0
# 9                              70.0       70.0
# 10                  30.0                                        30.0
# 11      210.0      100.0      120.0      180.0      210.0      100.0
# 12        5.0        5.0                              5.0        5.0
# 13                             50.0      100.0
# 14                                        60.0
# 15      15.99                                       15.99
# 16                 120.0                                       120.0
# 17                             40.0
# 18                             45.0
# 19                  80.0                  30.0                  80.0
#
#    2025-01-16 2025-01-23
# 8      1200.0
# 9        70.0       70.0
# 10
# 11      120.0      180.0
# 12
# 13       50.0      100.0
# 14                  60.0
# 15
# 16
# 17       40.0
# 18       45.0
# 19                  30.0
#
# [12 rows x 26 columns]

# %%
dataframe_revenus = create_df(df_revenus,"REVENUS",index_revenus)
dataframe_depenses = create_df(df_depense,"DEPENSES",index_depenses)

# %%
dataframe_revenus
# Out:
#          2024-08-01 2024-08-08 2024-08-15 2024-08-22  2024-08-29 2024-09-05  \
# REVENUS
# Salaire      3500.0                                       3500.0
#
#         2024-09-12 2024-09-19  2024-09-26 2024-10-03  ... 2024-11-21  \
# REVENUS                                               ...
# Salaire                            3500.0             ...     3500.0
#
#         2024-11-28  2024-12-05 2024-12-12 2024-12-19 2024-12-26  2025-01-02  \
# REVENUS
# Salaire                                       3500.0
#
#         2025-01-09 2025-01-16 2025-01-23
# REVENUS
# Salaire
#
# [1 rows x 26 columns]

# %%
dataframe_depenses
# Out:
#                2024-08-01 2024-08-08 2024-08-15 2024-08-22 2024-08-29  \
# DEPENSES
# Loyer              1200.0                                      1200.0
# Restaurant           60.0       60.0                  70.0       70.0
# Telephone                       30.0
# Shopping            210.0      180.0      120.0      130.0      200.0
# Coffee                5.0        5.0                              5.0
# Transports                      50.0       50.0       50.0       50.0
# Electricte                                            60.0
# Netflix             15.99
# Divers Amazon                  120.0
# Salle de sport                                        40.0
# Divers                                     45.0                  30.0
# Autres                                     80.0
#
#                2024-09-05 2024-09-12 2024-09-19 2024-09-26 2024-10-03  ...  \
# DEPENSES                                                               ...
# Loyer                                               1200.0             ...
# Restaurant           60.0                  70.0       70.0       60.0  ...
# Telephone                       30.0                                   ...
# Shopping            140.0      100.0      120.0      180.0      290.0  ...
# Coffee                           5.0                              5.0  ...
# Transports           50.0       50.0       50.0       50.0       50.0  ...
# Electricte                                            60.0             ...
# Netflix             15.99                                       15.99  ...
# Divers Amazon                                                          ...
# Salle de sport                             40.0                        ...
# Divers                          45.0                                   ...
# Autres                          80.0                  30.0             ...
#
#                2024-11-21 2024-11-28 2024-12-05 2024-12-12 2024-12-19  \
# DEPENSES
# Loyer              1200.0                                      1200.0
# Restaurant           70.0       70.0                             70.0
# Telephone                                             30.0
# Shopping            120.0      180.0      210.0      100.0      120.0
# Coffee                                      5.0        5.0
# Transports           50.0      100.0                             50.0
# Electricte                      60.0
# Netflix                                   15.99
# Divers Amazon                                        120.0
# Salle de sport       40.0                                        40.0
# Divers               45.0                                        45.0
# Autres                          30.0                  80.0
#
#                2024-12-26 2025-01-02 2025-01-09 2025-01-16 2025-01-23
# DEPENSES
# Loyer                                               1200.0
# Restaurant           70.0                             70.0       70.0
# Telephone                                  30.0
# Shopping            180.0      210.0      100.0      120.0      180.0
# Coffee                           5.0        5.0
# Transports          100.0                             50.0      100.0
# Electricte           60.0                                        60.0
# Netflix                        15.99
# Divers Amazon                             120.0
# Salle de sport                                        40.0
# Divers                                                45.0
# Autres               30.0                  80.0                  30.0
#
# [12 rows x 26 columns]

# %%
total_depenses =  sum_columns(dataframe_depenses)
print(total_depenses)
# Out:
#           Week  Balance
# 0   2024-08-01  1490.99
# 1   2024-08-08   445.00
# 2   2024-08-15   295.00
# 3   2024-08-22   350.00
# 4   2024-08-29  1555.00
# 5   2024-09-05   265.99
# 6   2024-09-12   310.00
# 7   2024-09-19   280.00
# 8   2024-09-26  1590.00
# 9   2024-10-03   420.99
# 10  2024-10-10   335.00
# 11  2024-10-17   325.00
# 12  2024-10-24  1640.00
# 13  2024-10-31   230.99
# 14  2024-11-07   420.99
# 15  2024-11-14   335.00
# 16  2024-11-21  1525.00
# 17  2024-11-28   440.00
# 18  2024-12-05   230.99
# 19  2024-12-12   335.00
# 20  2024-12-19  1525.00
# 21  2024-12-26   440.00
# 22  2025-01-02   230.99
# 23  2025-01-09   335.00
# 24  2025-01-16  1525.00
# 25  2025-01-23   440.00

# %%
total_revenus = sum_columns(dataframe_revenus)
print(total_revenus)
# Out:
#           Week  Balance
# 0   2024-08-01   3500.0
# 1   2024-08-08      0.0
# 2   2024-08-15      0.0
# 3   2024-08-22      0.0
# 4   2024-08-29   3500.0
# 5   2024-09-05      0.0
# 6   2024-09-12      0.0
# 7   2024-09-19      0.0
# 8   2024-09-26   3500.0
# 9   2024-10-03      0.0
# 10  2024-10-10      0.0
# 11  2024-10-17      0.0
# 12  2024-10-24   3500.0
# 13  2024-10-31      0.0
# 14  2024-11-07      0.0
# 15  2024-11-14      0.0
# 16  2024-11-21   3500.0
# 17  2024-11-28      0.0
# 18  2024-12-05      0.0
# 19  2024-12-12      0.0
# 20  2024-12-19   3500.0
# 21  2024-12-26      0.0
# 22  2025-01-02      0.0
# 23  2025-01-09      0.0
# 24  2025-01-16      0.0
# 25  2025-01-23      0.0

# %%
df_main = subtract_dataframes(total_revenus,total_depenses)
print(df_main)
# Out:
#           Week  Balance
# 0   2024-08-01  2009.01
# 1   2024-08-08  -445.00
# 2   2024-08-15  -295.00
# 3   2024-08-22  -350.00
# 4   2024-08-29  1945.00
# 5   2024-09-05  -265.99
# 6   2024-09-12  -310.00
# 7   2024-09-19  -280.00
# 8   2024-09-26  1910.00
# 9   2024-10-03  -420.99
# 10  2024-10-10  -335.00
# 11  2024-10-17  -325.00
# 12  2024-10-24  1860.00
# 13  2024-10-31  -230.99
# 14  2024-11-07  -420.99
# 15  2024-11-14  -335.00
# 16  2024-11-21  1975.00
# 17  2024-11-28  -440.00
# 18  2024-12-05  -230.99
# 19  2024-12-12  -335.00
# 20  2024-12-19  1975.00
# 21  2024-12-26  -440.00
# 22  2025-01-02  -230.99
# 23  2025-01-09  -335.00
# 24  2025-01-16 -1525.00
# 25  2025-01-23  -440.00

# %%
train_data, test_data = train_test_split(df_main, split_index=24)

# %%
plot_train_test_data(train_data=train_data, test_data=test_data)

# %% [markdown]
# **Triple explonential smoohting model fit**

# %%
preds_triple = exp_smoothing_model(train_data, test_data, model='triple')

# %%
exponential_smoothing_plot(train_data, test_data, preds_triple)

# %%
triple_rms = rms_error_calc(test_data, preds_triple)
print(" Root Mean Square Error of triple exponential method is:", triple_rms)
# Out:
#  Root Mean Square Error of triple exponential method is: 2444.06173463665

# %%
# Charger le modèle pré-entraîné
loaded_model = load_model(filename='trained_exp_smoothing_model.pkl')



# Prédire sur plusieurs semaines pour le nouveau client
predictions = predict_with_model(loaded_model, df_main, weeks_ahead=4)

flux_forecast = []

flux_forecast = predictions['Predicted_Balance']


forecast_balance = cumulative_addition(flux_forecast,1564.01)

print(forecast_balance)
# Out:
# [3493.7712592845846, 3161.0100898293776, 2798.201696606935, 2454.511213220051]

# %%
import matplotlib.pyplot as plt

# Visualiser les prédictions
plt.figure(figsize=(10, 6))
plt.plot(df_main['Week'], df_main['Balance'], label='Données historiques')
plt.plot(predictions['Week'], predictions['Predicted_Balance'], label='Prédictions', linestyle='--')
plt.xlabel('Week')
plt.ylabel('Balance')
plt.title('Prédictions de Balance pour un Nouveau Client')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 6
#       4 plt.figure(figsize=(10, 6))
#       5 plt.plot(df_main['Week'], df_main['Balance'], label='Données historiques')
# ----> 6 plt.plot(predictions['Week'], predictions['Predicted_Balance'], label='Prédictions', linestyle='--')
#       7 plt.xlabel('Week')
#       8 plt.ylabel('Balance')
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:2785, in plot(scalex, scaley, data, *args, **kwargs)
#    2783 @_copy_docstring_and_deprecators(Axes.plot)
#    2784 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2785     return gca().plot(
#    2786         *args, scalex=scalex, scaley=scaley,
#    2787         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_base.py:499, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     x, y = index_of(xy[-1])
#     498 if self.axes.xaxis is not None:
# --> 499     self.axes.xaxis.update_units(x)
#     500 if self.axes.yaxis is not None:
#     501     self.axes.yaxis.update_units(y)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1675, in Axis.update_units(self, data)
#    1672     self.set_units(default)
#    1674 elif neednew:
# -> 1675     self._update_axisinfo()
#    1676 self.stale = True
#    1677 return True
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axis.py:1687, in Axis._update_axisinfo(self)
#    1684 if self.converter is None:
#    1685     return
# -> 1687 info = self.converter.axisinfo(self.units, self)
#    1689 if info is None:
#    1690     return
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\dates.py:1930, in _SwitchableDateConverter.axisinfo(self, *args, **kwargs)
#    1929 def axisinfo(self, *args, **kwargs):
# -> 1930     return self._get_converter().axisinfo(*args, **kwargs)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\dates.py:1847, in DateConverter.axisinfo(self, unit, axis)
#    1839 """
#    1840 Return the `~matplotlib.units.AxisInfo` for *unit*.
#    1841
#    1842 *unit* is a `~datetime.tzinfo` instance or None.
#    1843 The *axis* argument is required but not used.
#    1844 """
#    1845 tz = unit
# -> 1847 majloc = AutoDateLocator(tz=tz,
#    1848                          interval_multiples=self._interval_multiples)
#    1849 majfmt = AutoDateFormatter(majloc, tz=tz)
#    1850 datemin = datetime.date(1970, 1, 1)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\dates.py:1337, in AutoDateLocator.__init__(self, tz, minticks, maxticks, interval_multiples)
#    1312 def __init__(self, tz=None, minticks=5, maxticks=None,
#    1313              interval_multiples=True):
#    1314     """
#    1315     Parameters
#    1316     ----------
#    (...)
#    1335         at 6 hour intervals.
#    1336     """
# -> 1337     super().__init__(tz=tz)
#    1338     self._freq = YEARLY
#    1339     self._freqs = [YEARLY, MONTHLY, DAILY, HOURLY, MINUTELY,
#    1340                    SECONDLY, MICROSECONDLY]
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\dates.py:1136, in DateLocator.__init__(self, tz)
#    1129 def __init__(self, tz=None):
#    1130     """
#    1131     Parameters
#    1132     ----------
#    1133     tz : str or `~datetime.tzinfo`, default: :rc:`timezone`
#    1134         Ticks timezone. If a string, *tz* is passed to `dateutil.tz`.
#    1135     """
# -> 1136     self.tz = _get_tzinfo(tz)
#
# File c:\Users\abdel\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\dates.py:234, in _get_tzinfo(tz)
#     232 if isinstance(tz, datetime.tzinfo):
#     233     return tz
# --> 234 raise TypeError("tz must be string or tzinfo subclass.")
#
# TypeError: tz must be string or tzinfo subclass.
